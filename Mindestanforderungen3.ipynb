# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stack-overflow-developer-survey-2025/survey_results_public_without_SO.csv")

# %%
df.pivot_table(index=['Country', 'EdLevel'], values=['JobSat', 'ConvertedCompYearly', 'WorkExp'], aggfunc='mean', dropna=True)
# Out:
#                                                                 ConvertedCompYearly  \
# Country     EdLevel
# Afghanistan Bachelor’s degree (B.A., B.S., B.Eng., etc.)                     4644.0
#             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                  4014.0
#             Primary/elementary school                                        9858.0
#             Professional degree (JD, MD, Ph.D, Ed.D, etc.)                      NaN
#             Secondary school (e.g. American high school, Ge...              65000.0
# ...                                                                             ...
# Zambia      Primary/elementary school                                           NaN
#             Some college/university study without earning a...               1717.0
# Zimbabwe    Bachelor’s degree (B.A., B.S., B.Eng., etc.)                    29000.0
#             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                 42500.0
# ...

# %%
df.pivot_table(index=['Country'], columns='EdLevel' , aggfunc='count', dropna=True)
# Out:
#                                                                    AIAcc  \
# EdLevel                              Associate degree (A.A., A.S., etc.)
# Country
# Afghanistan                                                          NaN
# Albania                                                              1.0
# Algeria                                                              NaN
# Andorra                                                              NaN
# Angola                                                               1.0
# ...                                                                  ...
# Venezuela, Bolivarian Republic of...                                 3.0
# Viet Nam                                                             5.0
# Yemen                                                                NaN
# Zambia                                                               NaN
# Zimbabwe                                                             NaN
#
# ...

# %% [markdown]
# <h1>Mindestanforderungen 1</h1>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Erstellen Sie NumPy-Arrays mit (Teil-)Daten aus Ihrem Projekt - es sollten verschiedene Datentypen (Ganzzahl, Kommazahl, String, Boolean, etc.) vorhanden sein

# %%
#array = np.array([
  #  [1, '25-34 years old', 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)', 'Ukraine', 61256.0],
   # [2, '25-34 years old', 'Associate degree (A.A., A.S., etc.)', 'Netherlands', 104413.0],
    #[3, '35-44 years old', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Ukraine', 53061.0],
    #[4, '35-44 years old', 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', 'Ukraine', 36197.0]])

df = pd.read_csv('./stack-overflow-developer-survey-2025/survey_results_public.csv')
array = df.to_numpy()

age = array[:, 3]
degree = array[:, 4]
#country = array[:, 3]
comp = array[:, -2].astype(np.float64)

print(comp)
# Out:
# [ 61256. 104413.  53061. ...     nan     nan     nan]

# %% [markdown]
# Filtern Sie ein NumPy-Array basierend auf mindestens 2 Bedingungen auf mindestens 2 Arrays/Spalten

# %%
filter = (country == 'Ukraine') & (comp > 50000)

result = array[filter]
print(result)
# Out:
# [['1' '25-34 years old' 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'
#   'Ukraine' '61256.0']
#  ['3' '35-44 years old' 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'
#   'Ukraine' '53061.0']]

# %% [markdown]
# Berechnen Sie mind. 2 Statistiken auf mind. 2 Arrays

# %%
mean_comp = np.mean(comp)
median_comp = np.median(comp)
std_comp = np.std(comp)

print("Einkommensstatistiken:")
print(f"Mittelwert: {mean_comp}")
print(f"Median: {median_comp}")
print(f"Standardabweichung: {std_comp}")

#countries, counts = np.unique(country, return_counts=True)
#print("Länderhäufigkeiten:")
#print(f"Länder: {countries}")
#print(f"Anzahl {counts}")
# Out:
# Einkommensstatistiken:
# Mittelwert: nan
# Median: nan
# Standardabweichung: nan

# %% [markdown]
# Laden Sie eine Datei von der Festplatte oder einer URL als pandas-DataFrame

# %%
df = pd.read_csv('./stack-overflow-developer-survey-2025/survey_results_public.csv')

df
# Out:
#        ResponseId                      MainBranch              Age  \
# 0               1  I am a developer by profession  25-34 years old
# 1               2  I am a developer by profession  25-34 years old
# 2               3  I am a developer by profession  35-44 years old
# 3               4  I am a developer by profession  35-44 years old
# 4               5  I am a developer by profession  35-44 years old
# ...           ...                             ...              ...
# 49118       49119  I am a developer by profession  25-34 years old
# 49119       49120  I am a developer by profession  35-44 years old
# 49120       49121  I am a developer by profession  25-34 years old
# 49121       49122  I am a developer by profession  25-34 years old
# 49122       49123  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %% [markdown]
# Fügen Sie mindestens eine neue Spalte hinzu, die aus mindestens einer anderen Spalte berechnet wurde

# %%
monhtly_comp = df["ConvertedCompYearly"] / 12

pos = df.columns.get_loc("ConvertedCompYearly")
df.insert(pos + 1, "ConvertedCompMonthly", monhtly_comp)

print(df[["ConvertedCompYearly", "ConvertedCompMonthly"]].head())
# Out:
#    ConvertedCompYearly  ConvertedCompMonthly
# 0              61256.0           5104.666667
# 1             104413.0           8701.083333
# 2              53061.0           4421.750000
# 3              36197.0           3016.416667
# 4              60000.0           5000.000000

# %% [markdown]
# Ändern Sie Reihenfolge und Benennung der Spalten

# %%
print(df.columns)

df.rename(columns={"ResponseId": "ID"}, inplace=True)

cols = list(df.columns)  

i1, i2 = cols.index("ConvertedCompYearly"), cols.index("ConvertedCompMonthly")

cols[i1], cols[i2] = cols[i2], cols[i1]

df = df[cols]
print(df.columns)
# Out:
# Index(['ID', 'MainBranch', 'Age', 'EdLevel', 'Employment', 'EmploymentAddl',
#        'WorkExp', 'LearnCodeChoose', 'LearnCode', 'LearnCodeAI',
#        ...
#        'AIAgentObserveSecure', 'AIAgentObsWrite', 'AIAgentExternal',
#        'AIAgentExtWrite', 'AIHuman', 'AIOpen', 'ConvertedCompYearly',
#        'ConvertedCompMonthly', 'JobSat', 'HasMasterDegree'],
#       dtype='object', length=172)
# Index(['ID', 'MainBranch', 'Age', 'EdLevel', 'Employment', 'EmploymentAddl',
#        'WorkExp', 'LearnCodeChoose', 'LearnCode', 'LearnCodeAI',
#        ...
#        'AIAgentObserveSecure', 'AIAgentObsWrite', 'AIAgentExternal',
#        'AIAgentExtWrite', 'AIHuman', 'AIOpen', 'ConvertedCompMonthly',
#        'ConvertedCompYearly', 'JobSat', 'HasMasterDegree'],
#       dtype='object', length=172)

# %% [markdown]
# Löschen Sie mindestens eine Spalte

# %%
df.drop(columns=['Employment'], inplace=True)

# %% [markdown]
# Verwenden Sie mindestens eine Funtion aus dem *str*-Accessor

# %%
df["HasMasterDegree"] = df["EdLevel"].str.contains("Master", case=False, na=False)

print(df[["EdLevel", "HasMasterDegree"]].head())
# Out:
#                                            EdLevel  HasMasterDegree
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)             True
# 1              Associate degree (A.A., A.S., etc.)            False
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)            False
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)            False
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)             True

# %% [markdown]
# Speichern Sie Ihr pandas DataFrame in eine Datei

# %%
df.to_csv('/stack-overflow-developer-survey-2025/modified_survey_results.csv', index=False)

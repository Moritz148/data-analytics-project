# %% [markdown]
# # Mindestanforderungen 5 - Clustering
# - Clusteranalyse durchführen
#     - wir haben eine Clusteranalyse auf einen zuvor bereinigten Datensatz mit MiniBatchKMeans durchgeführt
#     - Feature-Set waren hierbei eine Kombination aus numerischen und Textspalten.
#     - Ziel war es einen groben Überblick über die Entwicklerprofile zu erhalten
# - Parameter
#     - die Clusteranzahl haben wir über die unüberwachte Evaluationsmethode, mit der Elbow-Methode, gewählt
#     - dazu wurden jeweils die Inertia (Sum of Squared Errors) für k von 2-20 berechnet, geplottet und anschließend die passendste Clustergröße gewählt
#     - wir haben uns gegen die überwachte Evaluationsmethode entschieden, da wir keine überwachten Metriken haben
#     - Silhouetten-Score wurde nicht betrachtet, da schwer erklärbar
# - erzeugte Cluster
#     - Cluster zeigen sinnvolle Profile
#     - Teilweise entstehen Cluster, die stark durch Missingness geprägt sind, kommt durch viele fehlende Werte im Datensatz
# - Weiter Nutzung
#     - wir wollen die Cluster als "Entwicklerprofile" interpretieren und pro Cluster Kennzahlen oder typische Tools reporten
#     - zudem konnten wir bereits durch mehrere Iterationen des Clusterings Outlier erkennen und diese im Cleanup-Notebook ausschließen, da sie klare Datenfehler waren (Gehalt extrem hoch, WorkExp und YearsCode ~100)

# %% [markdown]
# Einlesen des Datensatzes, welcher zuvor im `Cleanup`-Notebook vorbereitet wurde

# %%
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.sparse import hstack, csr_matrix
from sklearn.cluster import MiniBatchKMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# - da ohne die untere Grenze des Gehalts teilweise mini-Cluster entstehen, legen wir eine untere Grenze bei 1000 USD fest

# %%
df = pd.read_csv("survey_results_cleaned_final.csv")
print("Loaded:", df.shape)
salary_col = "ConvertedCompTotal"
before = df.shape
df = df.dropna(subset=[salary_col])
df = df[df[salary_col] > 1000]
print(f"Dropped salary NaNs ({salary_col}): {before} -> {df.shape}")
# Out:
# Loaded: (18603, 38)
# Dropped salary NaNs (ConvertedCompTotal): (18603, 38) -> (14024, 38)

# %% [markdown]
# - Alle numerischen Spalten zwischenspeichern
# - einzelne Spalten, welche für Clustering nicht benötigt werden oder Cluster verzerren, entfernen (Age wird als String im Datensatz vorhanden sein)
# - durch `num_imputer` werden NaN-Werte spaltenweise durch Median der jeweiligen Spalte ersetzt (nicht immer sinnvoll)
#     - wenn NaN gedroppt werden würde, würden wir viele Spalten verlieren, Median ist zudem robust gegen Ausreißer
# - `StandardScaler` macht jede numerische Spalte vergleichbar durch z-Score Scaling
#     - Scaling wichtig, da sonst Features mit großen Zahlenbereichen alles dominieren würden
#     - für KMeans praktisch pflicht, da sonst Distanzen nicht fair
# - ConvertedCompTotal wird zusätzlich per `log1p` transformiert, um Ausreißer-Effekte zu reduzieren

# %%
num_cols_all = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
drop_num = {"ResponseId", "AgeNum", "RemoteCategoryNum"}  # falls vorhanden
num_cols = [c for c in num_cols_all if c not in drop_num]

X_num_raw = df[num_cols].apply(pd.to_numeric, errors="coerce")

if salary_col in X_num_raw.columns:
    df[f"{salary_col}_raw"] = X_num_raw[salary_col]          # fürs spätere Reporting
    X_num_raw[salary_col] = np.log1p(X_num_raw[salary_col])  # fürs Clustering

num_imputer = SimpleImputer(strategy="median")
num_scaler = StandardScaler()

X_num_imp = num_imputer.fit_transform(X_num_raw)
X_num = num_scaler.fit_transform(X_num_imp)

print("Numeric cols:", len(num_cols))
# Out:
# Numeric cols: 5

# %% [markdown]
# - Zwischenspeichern aller Text-/Kategoriespalten -> für TF-IDF später
# - herausfiltern einzelner Spalten, analog numerischer Spalten
#     - Country: Demografischer Aspekt weglassen
# - erkennen der Multi-Select Spalten anhand des Semikolons (wenn Anteil Semikolons höher der Schwelle -> Multi-Select
#     - Multi-Select wird später anders tokenisiert werden, da es zuerst gesplittet werden muss und mehrere Tokens pro Zeile gibt
# - Aufteilen der Mulit-Select und Single-Select spalten für späteres Dokument bauen mit dem TF-IDF Vectorizer
# - Herausfiltern der Single-Choice Freitext Felder
#     - Spalten mit 2-200 verschiedenen Einträgen werden behalten, 200 als grober Richtwert

# %%
obj_cols_all = df.select_dtypes(include=["object"]).columns.tolist()

# Spalten, die häufig dominieren / wenig Profilwert haben
hard_exclude = {"Country"}  # optional erweitern
obj_cols_all = [c for c in obj_cols_all if c not in hard_exclude]
obj_cols_all = [c for c in obj_cols_all if "Choice" not in c]

def is_multiselect(col, threshold=0.05):
    s = df[col].astype(str)
    return (s.str.contains(";", na=False).mean() >= threshold)

multi_cols = [c for c in obj_cols_all if is_multiselect(c)]
single_cols = [c for c in obj_cols_all if c not in multi_cols]

# Single-choice: zu viele Uniques = eher Freitext => raus
nunique = df[single_cols].nunique(dropna=True)
single_cols = nunique[(nunique >= 2) & (nunique <= 200)].index.tolist()

print("Multi cols:", len(multi_cols))
print("Single cols:", len(single_cols))
# Out:
# Multi cols: 9
# Single cols: 14

# %%
TOPN = 10

def build_top_map_for_multicols(df, multi_cols, topn=10):
    top_map = {}
    for col in multi_cols:
        s = df[col].dropna().astype(str)
        items = s.str.split(";").explode().str.strip().str.lower()
        items = items[items != ""]
        top_vals = items.value_counts().head(topn).index.tolist()
        top_map[col] = set(top_vals)
    return top_map

top_map = build_top_map_for_multicols(df, multi_cols, topn=TOPN)
print("Top-map built for multi-cols:", len(top_map))
# Out:
# Top-map built for multi-cols: 9

# %% [markdown]
# - hier werden aus einzelnen Zeilen Dokumente gebaut für Vectorizer
# - `parse_semicolon_list` erzeugt leere Listen, wenn NaN-Werte vorhanden sind, ansonsten splitten nach Semikolon und alles lowercase machen für besseres Handling
# - `normalize_token` ersezte Leerzeichen mit Unterstrichen und setzt den token auf lowercase
#     - dadurch wird verhindert, dass aus bspw. `visual studio code` nicht als drei getrennte Tokens erkannt werden
# - bei `row_to_doc` werden dann pro person bzw. Zeile eine Liste von Tokens erzeugt
#     - am Ende aus allen Tokens ein großer String im Stil `Spalte_Wert`
#     - NaN-Werte werden geskippt, da uns eigentlich ja nur ausgefüllt Werte interessieren
# - Warum das Ganze?
#     - der TFIDF-Vectorizer erwartet eine Liste an Dokumenten, weshalb wir für jede Zeile/Person ein Dokument bauen

# %%
def parse_semicolon_list(x):
    if pd.isna(x):
        return []
    s = str(x).strip()
    if s == "":
        return []
    return [p.strip().lower() for p in s.split(";") if p.strip()]

def normalize_token(t: str) -> str:
    t = t.strip().lower()
    t = re.sub(r"\s+", "_", t)
    return t

def row_to_doc(row) -> str:
    tokens = []

    for col in multi_cols:
        seen_other = False

        for t in parse_semicolon_list(row[col]):  # liefert lowercase
            if t in top_map[col]:
                tokens.append(f"{col}__{normalize_token(t)}")
            else:
                seen_other = True

        if seen_other:
            tokens.append(f"{col}__other")

    # Single-choice (wie gehabt)
    for col in single_cols:
        v = row[col]
        if pd.isna(v):
            continue
        v = str(v).strip()
        if v:
            tokens.append(f"{col}__{normalize_token(v)}")

    return " ".join(tokens)

docs = df.apply(row_to_doc, axis=1)

# %% [markdown]
# - hier werden aus den zuvor erzeugten Dokumenten eine numerische Feature-Matrix erstellt, um später alles zusammenzuwerfen und zu clustern
# - TFIDF-Vectorizer
#     - macht Matrix aus Spalte_Wert:
#         - Zeilen/Dokumente = Personen
#         - Spalten = Tokens
#         - Werte = TFIDF-Gewichte, also wie "typisch" der Token für die Person ist
#     - Tokens sind durch Leerzeichen getrennt, deshalb `str.split`
#     - `token_pattern = None`, weil Vectorizer sonst sein eigenes Tokenizing erzwingen würde
#     - `lowercase=False`, wurde vorher schon erledigt, wäre hier redundant
#     - *minimum document frequency* -> ein Token muss in mindestens 50 Personen vorkommen, sonst fliegt er raus
#         - so können extrem seltene Tokens rausgeworfen werden, die eher Nischen widerspiegeln
#     - *max features*, begrenzt Anzahl der Tokenspalten auf 10.000
#     - `fit_transform` baut Vokabular aus Tokens und erstellt Sparse Matrix der TFIDF Werte

# %%
vectorizer = TfidfVectorizer(
    tokenizer=str.split,
    token_pattern=None,
    lowercase=False,
    min_df=50,
    max_features=10000
)

X_text = vectorizer.fit_transform(docs)
print("TF-IDF shape:", X_text.shape)
# Out:
# TF-IDF shape: (14024, 200)

# %% [markdown]
# - Zusammenfügen der Numerischen und Textuellen Features zu gemeinsamen Feature Set für Clustering
# - `X_num` kommt vom StandardScaler der numerischen Werte
# - `X_text` kommt aus dem TFIDF Vectorizer
# - `hstack` = horizontal stack -> Features nebeneinander
#     - so sind weiterhin gleiche Anzahl an Zeilen/Personen
#     - aber Spalten sind nun numerische Features und TFIDF-Tokens
# - `.tocsr()` konvertiert resultierende Matrix explizit in CSR Format (Compressed Row Storage)
#     - *The CSR format is optimized for fast row slicing and matrix-vector products. It compresses the sparse matrix by storing only the non-zero elements and the corresponding row indices. The structure is divided into three one-dimensional arrays*

# %%
X_all = hstack([csr_matrix(X_num), X_text]).tocsr()
print("Final X_all shape:", X_all.shape)
# Out:
# Final X_all shape: (14024, 205)

# %% [markdown]
# - Anzahl Cluster von 2-20 testen
# - `inertias` sammelt die jeweilige Inertias Qualität für das k
# - `MiniBatchKMeans` ist eine Variante von KMeans, welche schneller bei großen/hohen Dimensionen ist, weil sie eben in Minibatches arbeitet
#     - sinnvoll, da unser Datensatz groß ist
# - `km_tmp.inertia_` summiert die quadrierten Abstände aller Punkte, somit können wir in dem Graphen den Elbow suchen und anschließend das beste *k* auswählen

# %%
k_values = list(range(2, 21))
inertias = []

for kk in k_values:
    km_tmp = MiniBatchKMeans(n_clusters=kk, random_state=42, batch_size=2048, n_init=10)
    km_tmp.fit(X_all)
    inertias.append(km_tmp.inertia_)

plt.figure(figsize=(9, 6))
plt.plot(k_values, inertias, marker="o")
plt.xlabel("k (Anzahl Cluster)")
plt.ylabel("Inertia (Within-Cluster SSE)")
plt.title("Elbow-Methode (Auto-Spalten TF-IDF + Numerik, MiniBatchKMeans)")
plt.grid(True)
plt.show()

# %% [markdown]
# - aus Elbowplot wurde k=6 am besten empfunden
# - Silhouette weggelassen, da er schwer erklärbar ist
# - anschließend Clustering-Modell erstellen mit denselben Parametern wie zuvor
# - `fit.predict` durch das *fit* "lernt" das Modell die 6 Clusterzentren auf Basis der zuvor erstellten Feature-Matrix`X_all`, *predict* weist anschließend jede Zeile/Person einem Cluster zu

# %%
k = 6
km = MiniBatchKMeans(n_clusters=k, random_state=42, batch_size=2048, n_init=10)
labels = km.fit_predict(X_all)

# %% [markdown]
# - hier werden interpretierbare Cluster erstellt
# - Wir erhalten die:
#     - Clustergrößen
#     - Numerik-Mittelwerte
#     - Cluster-Zentren
#     - Top TFIDF Tokens pro Cluster
#     - optional: TF-IDF Enrichment (Lift) pro Cluster gegenüber Gesamt
#         - zusätzlich zu den Top-Tokens betrachten wir Lift
#         - lift > 1: Token im Cluster überdurchschnittlich typisch (guter Cluster-Marker)
#         - Lift ~ 1: Token im Cluster ähnlich häufig wie in Gesamtdatensatz
#         - Lift < 1: Token im Cluster unterrepräsentiert
#         - so finden wir Tokens, die ein Cluster wirklich vom Gesamtdatensatz abheben

# %%
df_out = df.copy()
df_out["cluster"] = labels

# A) Clustergrößen + Prozent
sizes = df_out["cluster"].value_counts().sort_index()
summary = pd.DataFrame({
    "n": sizes,
    "pct": (sizes / sizes.sum() * 100).round(2)
})
print("\nClustergrößen:")
print(summary)

report_num_cols = num_cols.copy()
if f"{salary_col}_raw" in df_out.columns and salary_col in report_num_cols:
    report_num_cols = [c for c in report_num_cols if c != salary_col] + [f"{salary_col}_raw"]

# B) Numerik-Mittelwerte pro Cluster (Original-Skala)
print("\nNumerik-Mittelwerte pro Cluster (Original-Skala):")
print(df_out.groupby("cluster")[report_num_cols].mean().round(2))

# C) Numerik-Zentren (aus KMeans-Zentren zurücktransformiert)
centers_scaled_num = km.cluster_centers_[:, :len(num_cols)]
centers_num = num_scaler.inverse_transform(centers_scaled_num)
centers_num = pd.DataFrame(centers_num, columns=num_cols)
centers_num.index.name = "cluster"

if salary_col in centers_num.columns:
    centers_num[salary_col] = np.expm1(centers_num[salary_col])

print("\nCluster-Zentren (Numerik, Original-Skala):")
print(centers_num.round(2))

# D) Top TF-IDF Tokens pro Cluster
terms = vectorizer.get_feature_names_out()
centers_text = km.cluster_centers_[:, len(num_cols):]

top_n = 12
print("\nTop TF-IDF Tokens pro Cluster:")
for cl in range(km.n_clusters):
    top_idx = np.argsort(centers_text[cl])[::-1][:top_n]
    print(f"\nCluster {cl} (n={int(sizes.get(cl, 0))}):")
    for j in top_idx:
        print(f"  {terms[j]}  ({centers_text[cl][j]:.4f})")

terms = vectorizer.get_feature_names_out()

overall = np.asarray(X_text.mean(axis=0)).ravel()   # durchschnittliches TF-IDF je Token gesamt

TOP = 12
min_mean_cluster = 0.005   # schützt vor "Lift wegen winzigen Werten" (ggf. anpassen)
min_overall = 0.001        # optional

# optional: bestimmte Tokens ignorieren (Missingness/none)
ignore = (
    (np.char.find(terms.astype(str), "_nan") >= 0) |
    (np.char.find(terms.astype(str), "__none") >= 0)
)

print("\nTop TF-IDF Enrichment pro Cluster (Lift gegenüber Gesamt):")
for cl in range(km.n_clusters):
    mask = (labels == cl)
    n_cl = int(mask.sum())
    if n_cl == 0:
        continue

    mean_cl = np.asarray(X_text[mask].mean(axis=0)).ravel()

    lift = (mean_cl + 1e-12) / (overall + 1e-12)
    diff = mean_cl - overall

    valid = (mean_cl >= min_mean_cluster) & (overall >= min_overall) & (~ignore)

    idx = np.argsort(np.where(valid, lift, -np.inf))[::-1][:TOP]

    print(f"\nCluster {cl} (n={n_cl}):")
    for j in idx:
        if not valid[j]:
            continue
        print(f"  {terms[j]} | mean_tf_idf={mean_cl[j]:.4f} overall={overall[j]:.4f} "
              f"lift={lift[j]:.2f} diff={diff[j]:+.4f}")
# Out:
# Clustergrößen:
#             n    pct
# cluster
# 0        3649  26.02
# 1        2921  20.83
# 2        2069  14.75
# 3        1792  12.78
# 4        2231  15.91
# 5        1362   9.71
#
# Numerik-Mittelwerte pro Cluster (Original-Skala):
#          Unnamed: 0  WorkExp  YearsCode  JobSatisfaction  \
# cluster
# 0           9692.07     9.63      14.11             8.10
# 1          34818.55     6.80      10.82             7.76
# 2          36886.94    18.85      24.33             7.44
# 3          17385.95     9.18      13.96             4.11
# 4          13039.23    24.15      30.04             7.72
# 5          22850.44     5.31       8.66             7.01
#
#          ConvertedCompTotal_raw
# cluster
# 0                      99336.46
# 1                      79203.22
# 2                     119221.53
# 3                      86910.97
# 4                     124525.99
# 5                      11613.54
#
# Cluster-Zentren (Numerik, Original-Skala):
#          Unnamed: 0  WorkExp  YearsCode  JobSatisfaction  ConvertedCompTotal
# cluster
# 0           9522.52    10.03      14.43             8.15            86623.46
# 1          33899.75     6.69      10.71             7.84            66726.67
# 2          36908.58    18.49      23.85             7.32           103474.24
# 3          15969.82     9.03      13.75             4.36            76035.01
# 4          14105.76    24.19      30.27             7.83           109097.92
# 5          23152.25     5.47       8.62             7.05             9024.57
#
# Top TF-IDF Tokens pro Cluster:
#
# Cluster 0 (n=3649):
#   Employment__employed  (0.0732)
#   ICorPM__individual_contributor  (0.0713)
#   AIThreat__no  (0.0706)
#   MainBranch__i_am_a_developer_by_profession  (0.0705)
#   PlatformHaveWorkedWith__other  (0.0697)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0693)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0690)
#   PlatformHaveWorkedWith__docker  (0.0674)
#   Age__25-34_years_old  (0.0670)
#   LanguageHaveWorkedWith__other  (0.0669)
#   CommPlatformHaveWorkedWith__github_(public_projects,_not_private_repos)  (0.0660)
#   NewRole__i_have_neither_consider_or_transitioned_into_a_new_career_or_industry  (0.0658)
#
# Cluster 1 (n=2921):
#   Age__25-34_years_old  (0.0900)
#   ICorPM__individual_contributor  (0.0749)
#   Employment__employed  (0.0732)
#   MainBranch__i_am_a_developer_by_profession  (0.0711)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0701)
#   AIThreat__no  (0.0692)
#   DevEnvsHaveWorkedWith__visual_studio_code  (0.0673)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0671)
#   CommPlatformHaveWorkedWith__reddit  (0.0662)
#   LanguageHaveWorkedWith__python  (0.0661)
#   PlatformHaveWorkedWith__other  (0.0661)
#   CommPlatformHaveWorkedWith__github_(public_projects,_not_private_repos)  (0.0649)
#
# Cluster 2 (n=2069):
#   Age__35-44_years_old  (0.0906)
#   MainBranch__i_am_a_developer_by_profession  (0.0703)
#   Employment__employed  (0.0686)
#   PlatformHaveWorkedWith__other  (0.0684)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0682)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0676)
#   LearnCodeAI__yes,_i_learned_how_to_use_ai-enabled_tools_required_for_my_job_or_to_benefit_my_career  (0.0675)
#   LanguageHaveWorkedWith__javascript  (0.0655)
#   LanguageHaveWorkedWith__sql  (0.0650)
#   DevEnvsHaveWorkedWith__visual_studio_code  (0.0647)
#   LanguageHaveWorkedWith__other  (0.0644)
#   CommPlatformHaveWorkedWith__github_(public_projects,_not_private_repos)  (0.0643)
#
# Cluster 3 (n=1792):
#   MainBranch__i_am_a_developer_by_profession  (0.0763)
#   ICorPM__individual_contributor  (0.0749)
#   Age__25-34_years_old  (0.0746)
#   Employment__employed  (0.0737)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0691)
#   PlatformHaveWorkedWith__other  (0.0682)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0679)
#   LanguageHaveWorkedWith__other  (0.0678)
#   OfficeStackAsyncHaveWorkedWith__jira  (0.0673)
#   CommPlatformHaveWorkedWith__reddit  (0.0663)
#   PlatformHaveWorkedWith__docker  (0.0655)
#   DevEnvsHaveWorkedWith__visual_studio_code  (0.0653)
#
# Cluster 4 (n=2231):
#   Age__45-54_years_old  (0.1138)
#   MainBranch__i_am_a_developer_by_profession  (0.0698)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0696)
#   LanguageHaveWorkedWith__sql  (0.0693)
#   NewRole__i_have_neither_consider_or_transitioned_into_a_new_career_or_industry  (0.0692)
#   Employment__employed  (0.0677)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0665)
#   PlatformHaveWorkedWith__other  (0.0665)
#   LanguageHaveWorkedWith__other  (0.0663)
#   LanguageHaveWorkedWith__javascript  (0.0662)
#   AIThreat__no  (0.0655)
#   LanguageHaveWorkedWith__html/css  (0.0652)
#
# Cluster 5 (n=1362):
#   Age__18-24_years_old  (0.0917)
#   Industry__software_development  (0.0724)
#   ICorPM__individual_contributor  (0.0707)
#   CommPlatformHaveWorkedWith__youtube  (0.0706)
#   OfficeStackAsyncHaveWorkedWith__github  (0.0689)
#   AISelect__yes,_i_use_ai_tools_daily  (0.0682)
#   CommPlatformHaveWorkedWith__stack_overflow  (0.0679)
#   LanguageHaveWorkedWith__javascript  (0.0668)
#   EdLevel__bachelor’s_degree  (0.0664)
#   MainBranch__i_am_a_developer_by_profession  (0.0663)
#   DevEnvsHaveWorkedWith__visual_studio_code  (0.0662)
#   LanguageHaveWorkedWith__other  (0.0661)
#
# Top TF-IDF Enrichment pro Cluster (Lift gegenüber Gesamt):
#
# Cluster 0 (n=3649):
#   Age__25-34_years_old | mean_tf_idf=0.0704 overall=0.0530 lift=1.33 diff=+0.0174
#   DevType__data_scientist | mean_tf_idf=0.0064 overall=0.0050 lift=1.29 diff=+0.0014
#   Industry__media_&_advertising_services | mean_tf_idf=0.0094 overall=0.0078 lift=1.21 diff=+0.0016
#   LearnCodeAI__no,_i_learned_something_that_was_not_related_to_ai_or_ai_enablement_for_my_personal_curiosity_and/or_hobbies | mean_tf_idf=0.0284 overall=0.0237 lift=1.20 diff=+0.0047
#   MainBranch__i_am_not_primarily_a_developer,_but_i_write_code_sometimes_as_part_of_my_work/studies | mean_tf_idf=0.0142 overall=0.0121 lift=1.17 diff=+0.0021
#   LearnCodeAI__yes,_i_learned_how_to_use_ai-enabled_tools_for_my_personal_curiosity_and/or_hobbies | mean_tf_idf=0.0542 overall=0.0464 lift=1.17 diff=+0.0078
#   DevEnvsHaveWorkedWith__neovim | mean_tf_idf=0.0301 overall=0.0258 lift=1.17 diff=+0.0044
#   AIAgents__no,_and_i_don't_plan_to | mean_tf_idf=0.0615 overall=0.0530 lift=1.16 diff=+0.0085
#   Age__35-44_years_old | mean_tf_idf=0.0577 overall=0.0506 lift=1.14 diff=+0.0071
#   PlatformHaveWorkedWith__yarn | mean_tf_idf=0.0393 overall=0.0347 lift=1.13 diff=+0.0046
#   NewRole__i_have_transitioned_into_a_new_career_and/or_industry_voluntarily | mean_tf_idf=0.0232 overall=0.0205 lift=1.13 diff=+0.0027
#   NewRole__i_have_neither_consider_or_transitioned_into_a_new_career_or_industry | mean_tf_idf=0.0652 overall=0.0578 lift=1.13 diff=+0.0074
#
# Cluster 1 (n=2921):
#   Age__25-34_years_old | mean_tf_idf=0.0901 overall=0.0530 lift=1.70 diff=+0.0371
#   DevType__data_engineer | mean_tf_idf=0.0113 overall=0.0073 lift=1.56 diff=+0.0041
#   DevType__academic_researcher | mean_tf_idf=0.0080 overall=0.0053 lift=1.51 diff=+0.0027
#   DevType__data_scientist | mean_tf_idf=0.0072 overall=0.0050 lift=1.46 diff=+0.0023
#   DevType__ai/ml_engineer | mean_tf_idf=0.0075 overall=0.0052 lift=1.45 diff=+0.0023
#   Age__18-24_years_old | mean_tf_idf=0.0296 overall=0.0217 lift=1.36 diff=+0.0079
#   AIAgents__no,_i_use_ai_exclusively_in_copilot/autocomplete_mode | mean_tf_idf=0.0396 overall=0.0309 lift=1.28 diff=+0.0087
#   OrgSize__i_don’t_know | mean_tf_idf=0.0053 overall=0.0043 lift=1.25 diff=+0.0011
#   DevType__developer,_front-end | mean_tf_idf=0.0174 overall=0.0139 lift=1.25 diff=+0.0035
#   AIAgent_Uses__cybersecurity | mean_tf_idf=0.0077 overall=0.0062 lift=1.25 diff=+0.0015
#   LearnCodeAI__no,_i_learned_something_that_was_not_related_to_ai_or_ai_enablement_as_required_for_my_job_or_to_benefit_my_career | mean_tf_idf=0.0304 overall=0.0255 lift=1.19 diff=+0.0049
#   DevType__developer,_embedded_applications_or_devices | mean_tf_idf=0.0129 overall=0.0108 lift=1.19 diff=+0.0021
#
# Cluster 2 (n=2069):
#   Age__45-54_years_old | mean_tf_idf=0.0598 overall=0.0307 lift=1.95 diff=+0.0291
#   DevType__senior_executive_(c-suite,_vp,_etc.) | mean_tf_idf=0.0073 overall=0.0040 lift=1.82 diff=+0.0033
#   Age__35-44_years_old | mean_tf_idf=0.0905 overall=0.0506 lift=1.79 diff=+0.0399
#   DevType__engineering_manager | mean_tf_idf=0.0150 overall=0.0089 lift=1.69 diff=+0.0061
#   MainBranch__i_used_to_be_a_developer_by_profession,_but_no_longer_am | mean_tf_idf=0.0054 overall=0.0032 lift=1.67 diff=+0.0022
#   Age__55-64_years_old | mean_tf_idf=0.0138 overall=0.0088 lift=1.56 diff=+0.0049
#   DevType__architect,_software_or_solutions | mean_tf_idf=0.0261 overall=0.0168 lift=1.56 diff=+0.0093
#   NewRole__i_have_transitioned_into_a_new_career_and/or_industry_involuntarily | mean_tf_idf=0.0087 overall=0.0059 lift=1.47 diff=+0.0028
#   ICorPM__people_manager | mean_tf_idf=0.0370 overall=0.0254 lift=1.46 diff=+0.0116
#   AIAgent_Uses__marketing | mean_tf_idf=0.0114 overall=0.0078 lift=1.45 diff=+0.0035
#   AISelect__no,_but_i_plan_to_soon | mean_tf_idf=0.0167 overall=0.0115 lift=1.44 diff=+0.0051
#   Employment__independent_contractor,_freelancer,_or_self-employed | mean_tf_idf=0.0320 overall=0.0224 lift=1.43 diff=+0.0096
#
# Cluster 3 (n=1792):
#   Employment__not_employed | mean_tf_idf=0.0093 overall=0.0031 lift=2.98 diff=+0.0062
#   NewRole__i_have_strongly_considered_changing_my_career_and/or_the_industry_i_work_in | mean_tf_idf=0.0684 overall=0.0272 lift=2.51 diff=+0.0412
#   DevType__developer,_qa_or_test | mean_tf_idf=0.0050 overall=0.0029 lift=1.74 diff=+0.0021
#   AIThreat__yes | mean_tf_idf=0.0415 overall=0.0275 lift=1.51 diff=+0.0140
#   Age__25-34_years_old | mean_tf_idf=0.0722 overall=0.0530 lift=1.36 diff=+0.0192
#   LearnCodeAI__no,_i_learned_something_that_was_not_related_to_ai_or_ai_enablement_for_my_personal_curiosity_and/or_hobbies | mean_tf_idf=0.0311 overall=0.0237 lift=1.31 diff=+0.0074
#   AISelect__no,_and_i_don't_plan_to | mean_tf_idf=0.0359 overall=0.0291 lift=1.23 diff=+0.0067
#   DevType__developer,_back-end | mean_tf_idf=0.0442 overall=0.0359 lift=1.23 diff=+0.0083
#   LearnCodeAI__no,_i_didn't_spend_time_learning_in_the_past_year | mean_tf_idf=0.0252 overall=0.0205 lift=1.23 diff=+0.0047
#   EdLevel__associate_degree | mean_tf_idf=0.0116 overall=0.0096 lift=1.20 diff=+0.0020
#   OfficeStackAsyncHaveWorkedWith__obsidian | mean_tf_idf=0.0378 overall=0.0314 lift=1.20 diff=+0.0064
#   DevType__ai/ml_engineer | mean_tf_idf=0.0061 overall=0.0052 lift=1.18 diff=+0.0009
#
# Cluster 4 (n=2231):
#   Age__55-64_years_old | mean_tf_idf=0.0404 overall=0.0088 lift=4.57 diff=+0.0316
#   Age__45-54_years_old | mean_tf_idf=0.1134 overall=0.0307 lift=3.69 diff=+0.0827
#   DevType__senior_executive_(c-suite,_vp,_etc.) | mean_tf_idf=0.0094 overall=0.0040 lift=2.33 diff=+0.0053
#   DevType__architect,_software_or_solutions | mean_tf_idf=0.0343 overall=0.0168 lift=2.04 diff=+0.0175
#   MainBranch__i_used_to_be_a_developer_by_profession,_but_no_longer_am | mean_tf_idf=0.0061 overall=0.0032 lift=1.91 diff=+0.0029
#   DevType__engineering_manager | mean_tf_idf=0.0149 overall=0.0089 lift=1.68 diff=+0.0060
#   Employment__independent_contractor,_freelancer,_or_self-employed | mean_tf_idf=0.0335 overall=0.0224 lift=1.50 diff=+0.0111
#   ICorPM__people_manager | mean_tf_idf=0.0374 overall=0.0254 lift=1.47 diff=+0.0120
#   AISelect__no,_but_i_plan_to_soon | mean_tf_idf=0.0169 overall=0.0115 lift=1.46 diff=+0.0053
#   Industry__internet,_telecomm_or_information_services | mean_tf_idf=0.0191 overall=0.0135 lift=1.41 diff=+0.0056
#   Industry__higher_education | mean_tf_idf=0.0125 overall=0.0092 lift=1.36 diff=+0.0033
#   Industry__computer_systems_design_and_services | mean_tf_idf=0.0092 overall=0.0068 lift=1.34 diff=+0.0023
#
# Cluster 5 (n=1362):
#   Employment__student | mean_tf_idf=0.0403 overall=0.0056 lift=7.18 diff=+0.0347
#   DevType__student | mean_tf_idf=0.0197 overall=0.0029 lift=6.81 diff=+0.0168
#   Age__18-24_years_old | mean_tf_idf=0.0908 overall=0.0217 lift=4.19 diff=+0.0691
#   OrgSize__just_me_-_i_am_a_freelancer,_sole_proprietor,_etc. | mean_tf_idf=0.0157 overall=0.0064 lift=2.45 diff=+0.0093
#   RemoteWork__in-person | mean_tf_idf=0.0563 overall=0.0268 lift=2.10 diff=+0.0295
#   AIAgent_Uses__robotics | mean_tf_idf=0.0060 overall=0.0028 lift=2.09 diff=+0.0031
#   EdLevel__secondary_school | mean_tf_idf=0.0259 overall=0.0124 lift=2.09 diff=+0.0135
#   AIModelsHaveWorkedWith__deepseek_(v-_general_purpose_models) | mean_tf_idf=0.0314 overall=0.0157 lift=1.99 diff=+0.0156
#   AIAgent_Uses__it_operations | mean_tf_idf=0.0276 overall=0.0146 lift=1.88 diff=+0.0129
#   OrgSize__i_don’t_know | mean_tf_idf=0.0074 overall=0.0043 lift=1.74 diff=+0.0031
#   AIModelsHaveWorkedWith__deepseek_(r-_reasoning_models) | mean_tf_idf=0.0398 overall=0.0233 lift=1.70 diff=+0.0164
#   DevEnvsHaveWorkedWith__android_studio | mean_tf_idf=0.0413 overall=0.0243 lift=1.70 diff=+0.0170

# %% [markdown]
# **Nur für Visualisierung**
# - Dimensions-Reduktion, die sehr hochdimensionale Matrix auf 2 Komponenten herunterbricht
# - TruncatedSVD funktioniert gut für sparse Matrizen, PCA zentriert meist und braucht dense Matrizen
# - zeichnet jeden Datenpunkt als Punkt im 2D-Raum eingefärbt nach Cluster

# %%
svd = TruncatedSVD(n_components=2, random_state=42)
X_2d = svd.fit_transform(X_all)

plt.figure(figsize=(9, 7))
plt.scatter(X_2d[:, 0], X_2d[:, 1], c=labels, s=6, alpha=0.6)
plt.title("Cluster (TF-IDF + Numerik) – 2D via TruncatedSVD")
plt.xlabel("SVD 1")
plt.ylabel("SVD 2")
plt.colorbar(label="Cluster")
plt.grid(True)
plt.show()

# %%
df.ConvertedCompTotal.describe()
# Out:
# count     14024.000000
# mean      91976.631253
# std       60415.528272
# min        1023.147418
# 25%       49047.600000
# 50%       81746.000000
# 75%      122619.000000
# max      323000.000000
# Name: ConvertedCompTotal, dtype: float64

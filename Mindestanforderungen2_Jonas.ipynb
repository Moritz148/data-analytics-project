# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("stack-overflow-developer-survey-2025/survey_results_public_without_SO.csv")

# %% [markdown]
# <h2>Überblick über Daten verschaffen, durch die generierung von Histogrammen für ausgewählte Spalten</h2>

# %% [markdown]
# <h3>1. MainBranch</h3>

# %%
counts = df['MainBranch'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Beruf / Haupttätigkeit')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung nach Haupttätigkeit')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>2. Age</h3>

# %%
counts = df['Age'].value_counts().head(10)

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Alter')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>3. EdLevel</h3>

# %%
counts = df['EdLevel'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Bildungslevel')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>4. Employment</h3>

# %%
counts = df['Employment'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Employment')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>5. Country</h3>

# %%
counts = df['Country'].value_counts().head(10)

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Land')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung Länder (Top 10)')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>6. WorkExp</h3>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlabel('Erfahrung in Jahren')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung Erfahrung in Jahren')
ax.hist(df['WorkExp'])
plt.show()

# %% [markdown]
# <h3>7. LearnCodeChoose</h3>

# %%
counts = df['LearnCodeChoose'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Antwort')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>8. LearnCode</h3>

# %%
counts = df['LearnCode'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))


bars = ax.bar(range(len(counts)), counts.values)

ax.set_xlabel('Antwort')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

#ax.legend(
 #   bars, counts.index,
  #  title="Antworten",
   # loc='upper center',
    #bbox_to_anchor=(0.5, -0.15),
    #ncol=2,
    #fontsize=9
#)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>9. LearnCodeAI</h3>

# %%
counts = df['LearnCodeAI'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Antwort')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('LearnCodeAI Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>10. AILearnHow</h3>

# %%
counts = df['AILearnHow'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

#colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values)

ax.set_xlabel('Antwort')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')

ax.set_xticks([])

#ax.legend(
 #   bars, counts.index,
  #  title="Antworten",
   # loc='upper center',
    #bbox_to_anchor=(0.5, -0.15),
    #ncol=2,
    #fontsize=9
#)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>11. YearsCode</h3>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.set_xlabel('YearsCode')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('Verteilung')
ax.hist(df['YearsCode'])
plt.show()

# %% [markdown]
# <h3>12. DevType</h3>

# %%
counts = df['DevType'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('DevType')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('DevType Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>13. RemoteWork</h3>

# %%
counts = df['RemoteWork'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('Antwort')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('RemoteWork Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>14. OrgSize</h3>

# %%
counts = df['OrgSize'].value_counts()

fig, ax = plt.subplots(figsize=(12, 6))

colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))

bars = ax.bar(range(len(counts)), counts.values, color=colors)

ax.set_xlabel('OrgSize')
ax.set_ylabel('Absolute Häufigkeit')
ax.set_title('OrgSize Verteilung')

ax.set_xticks([])

ax.legend(
    bars, counts.index,
    title="Antworten",
    loc='upper center',
    bbox_to_anchor=(0.5, -0.15),
    ncol=2,
    fontsize=9
)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h2>Line Charts</h2>

# %%
data = df[['ConvertedCompYearly', 'JobSat']].dropna().sort_values('ConvertedCompYearly')

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(data['ConvertedCompYearly'], data['JobSat'])

ax.set_xlabel('Jahreseinkommen (USD)')
ax.set_ylabel('Jobzufriedenheit')
ax.set_title('Jobzufriedenheit in Abhängigkeit vom Einkommen')

ax.ticklabel_format(style='plain', axis='x') 
ax.set_xlim(0, 1_000_000)

plt.tight_layout()
plt.show()

# %%
data = df[['ConvertedCompYearly', 'JobSat']].dropna().sort_values('ConvertedCompYearly')
data['JobSat_smooth'] = data['JobSat'].rolling(window=200, center=True).mean()

fig, ax = plt.subplots(figsize=(10,6))

ax.scatter(data['ConvertedCompYearly'], data['JobSat'], s=10, alpha=0.3, label='Einzeldaten')
ax.plot(data['ConvertedCompYearly'], data['JobSat_smooth'], color='red', linewidth=2, label='Trend (geglättet)')

ax.set_xlabel('Jahreseinkommen (USD)')
ax.set_ylabel('Jobzufriedenheit')
ax.set_title('Jobzufriedenheit in Abhängigkeit vom Einkommen')

ax.ticklabel_format(style='plain', axis='x') 
ax.set_xlim(0, 1_000_000)

ax.legend()
plt.tight_layout()
plt.show()

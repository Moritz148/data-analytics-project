# %% [markdown]
# <h1>Mindestanforderungen 5</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import cluster, datasets 
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
df = pd.read_csv("stack-overflow-developer-survey-2025/survey_results_public_without_SO.csv")

df.head()
# Out:
#                        MainBranch              Age  \
# 0  I am a developer by profession  25-34 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  35-44 years old
# 3  I am a developer by profession  35-44 years old
# 4  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# 4  Independent contractor, freelancer, or self-em...
#
# ...

# %%
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df.select_dtypes(include=[np.number]).dropna())

kmeans = cluster.KMeans(n_clusters=10, random_state=0, n_init=10).fit(data_scaled)

print(kmeans.labels_)

for i in range(0,10):
    print("Name:", i, "Größe: ", list(kmeans.labels_).count(i))


print(kmeans.cluster_centers_)
# Out:
# [1 1 1 ... 6 6 2]
# Name: 0 Größe:  2195
# Name: 1 Größe:  942
# Name: 2 Größe:  2001
# Name: 3 Größe:  7
# Name: 4 Größe:  1133
# Name: 5 Größe:  1977
# Name: 6 Größe:  2328
# Name: 7 Größe:  1
# Name: 8 Größe:  297
# Name: 9 Größe:  2334
# [[ 1.51366093e+00  1.53104334e+00 -3.06447590e-02  1.81658525e-02
#   -1.37155202e-01 -2.96097230e-02 -3.75991386e-02  6.20571494e-02
#    1.31995016e-02 -9.86665330e-02 -9.02354598e-02 -2.20153875e-01
#   -4.43360096e-02  9.97074930e-02 -1.30804334e-02  1.59717789e-02
#   -1.98342296e-01 -1.48358132e-01 -5.95065640e-02  7.58066495e-02
#   -1.52637074e-01 -1.54729552e-01 -1.17273629e-01  4.49186387e-01
#   -6.66035647e-02  8.79730346e-02 -2.36442655e-01  1.50626943e-01
#   -3.24990563e-01 -4.29076943e-02  1.01197105e-01 -2.55858721e-02
#   -5.69725142e-03  1.43370457e-01  5.98476450e-02 -1.01365865e-02
#   -4.21201185e-03 -2.71889171e-02  1.50474164e-01  2.25704793e-01]
#  [ 1.86365042e-01  1.80247472e-01  1.28250814e+00  2.21682510e-01
# ...

# %%
inertia = kmeans.inertia_
sil = metrics.silhouette_score(data_scaled,kmeans.labels_)

print(inertia)
print(sil)
# Out:
# 423110.8227238975
# 0.024344028616515564
